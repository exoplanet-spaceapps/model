# %% [markdown]
# # 02_tls_search — GP 去噪 + TLS 週期搜尋（示例）
# 需要：`pip install transitleastsquares`（GP：`pip install celerite2` 或 `starry_process`）

# %%
import numpy as np
from app.denoise.gp import denoise
from app.search.tls_runner import run_tls
t = np.linspace(0, 27.4, 7000)
flux = 1 + 0.0005*np.sin(2*np.pi*t/13.7) + np.random.default_rng(0).normal(0, 3e-4, size=t.shape)
resid, trend = denoise(t, flux, backend='auto')
res = run_tls(t, 1+resid)
res
